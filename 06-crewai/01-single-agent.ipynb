# %%
pip install crewai crewai-tools

# %%
pip install langtrace-python-sdk

# %%
import os
os.getenv("OPENAI_MODEL_NAME")
# Out:
# 'gpt-4o-mini'

# %%
# Must precede any llm module imports

from langtrace_python_sdk import langtrace
import os

langtrace.init(api_key = os.getenv("LANGTRACE_API_KEY"))
# Out:
# Initializing Langtrace SDK..
# ⭐ Leave our github a star to stay on top of our updates - https://github.com/Scale3-Labs/langtrace
# Exporting spans to GenAI..
# Langtrace Project URL: https://app.langtrace.ai/project/cmhhdkz730001xuyx3wwrx5bc/traces

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from crewai import Agent, Task, Crew
from textwrap import dedent

# Here backstory is list of capabilities that Agent can perform
# goal is high level overview of Agent
fin_advisor_agent = Agent(
    role="Financial Advisor",
    goal="Analyze customer financial situation and provide insights",
    backstory=dedent("""
        You are an experienced financial advisor in India with expertise in
         personal finanace management. You help clients understand their financial
         health and provide actionable insights.
    """)
)

# %%
fin_analysis_task = Task(
    agent=fin_advisor_agent,
    description=dedent("""
        Analyze the customer's financial situation based on the following inputs:
        - Monthly salary: {salary}
        - Monthly expenses: {expenses}
        - Current savings: {savings}
        - Current investments: {investments}
        - Outstanding loans: {loans}
        - Number of dependents: {dependents}
        
        Provide a detailed analysis including:
        1. Current financial health score (Good/Average/Needs Improvement)
        2. Monthly savings potential
        3. Debt-to-income ratio
        4. Basic recommendations for improvement
        
        Format the output as a structured report with clear sections
    """),
    expected_output=dedent("""
        A detailed financial analysis report with the following sections in markdown format without '```'
         - Financial Health Overview
         - Income and Expense Analysis
         - Savings Analysis
         - Debt Analysis
         - Key Recommendations
    """),
    output_file="analysis_task.md"
)

# %%
fin_advisory_crew = Crew(
    agents=[fin_advisor_agent],
    tasks=[fin_analysis_task],
    verbose=True
)

# %%
inputs = {
    "salary": "₹1,50,000",
    "expenses": "₹80,000",
    "savings": "₹5,00,000",
    "investments": "₹10,00,000",
    "loans": "₹20,00,000",
    "dependents": "2"
}

# %%
result = fin_advisory_crew.kickoff(inputs=inputs)

result
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 4db5d4fb-5e53-4361-b4b0-12de1c5ebdd5                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Financial Advisor                                                                                       │
# │                                                                                                                 │
# │  Task:                                                                                                          │
# │  Analyze the customer's financial situation based on the following inputs:                                      │
# │  - Monthly salary: ₹1,50,000                                                                                    │
# │  - Monthly expenses: ₹80,000                                                                                    │
# │  - Current savings: ₹5,00,000                                                                                   │
# │  - Current investments: ₹10,00,000                                                                              │
# │  - Outstanding loans: ₹20,00,000                                                                                │
# │  - Number of dependents: 2                                                                                      │
# │                                                                                                                 │
# │  Provide a detailed analysis including:                                                                         │
# │  1. Current financial health score (Good/Average/Needs Improvement)                                             │
# │  2. Monthly savings potential                                                                                   │
# │  3. Debt-to-income ratio                                                                                        │
# │  4. Basic recommendations for improvement                                                                       │
# │                                                                                                                 │
# │  Format the output as a structured report with clear sections                                                   │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Financial Advisor                                                                                       │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # Financial Health Overview                                                                                    │
# │  Based on the information provided, we will analyze your financial situation comprehensively. Your monthly      │
# │  salary is ₹1,50,000, while your monthly expenses total ₹80,000. You have savings of ₹5,00,000 and investments  │
# │  amounting to ₹10,00,000. Additionally, you have outstanding loans of ₹20,00,000 with 2 dependents. Overall,    │
# │  by evaluating these figures, we can assess your financial health and provide actionable insights.              │
# │                                                                                                                 │
# │  ## Current Financial Health Score: Average                                                                     │
# │  Considering your income, expenses, savings, investments, and outstanding loans, your current financial health  │
# │  score is **Average**. While your income is substantial, the outstanding debt reduces your security,            │
# │  warranting a need for financial strategy refinement.                                                           │
# │                                                                                                                 │
# │  # Income and Expense Analysis                                                                                  │
# │  - **Monthly Income:** ₹1,50,000                                                                                │
# │  - **Monthly Expenses:** ₹80,000                                                                                │
# │  - **Disposable Income:** ₹1,50,000 - ₹80,000 = **₹70,000**                                                     │
# │                                                                                                                 │
# │  Your disposable income is ₹70,000 per month, indicating a healthy margin after meeting essential expenses.     │
# │  This surplus can be redirected into savings and investments.                                                   │
# │                                                                                                                 │
# │  # Savings Analysis                                                                                             │
# │  - **Current Savings:** ₹5,00,000                                                                               │
# │  - **Monthly Savings Potential:** Given your disposable income of ₹70,000, you could potentially save this      │
# │  amount each month.                                                                                             │
# │    - **Annual Savings Potential:** ₹70,000 x 12 = **₹8,40,000**                                                 │
# │                                                                                                                 │
# │  Assuming no expenses increase and prudent spending, your savings could grow substantially.                     │
# │                                                                                                                 │
# │  # Debt Analysis                                                                                                │
# │  - **Outstanding Loans:** ₹20,00,000                                                                            │
# │  - **Debt-to-Income Ratio (DTI):**                                                                              │
# │    - Monthly debt obligations (assuming a typical installment of ₹30,000/month on loans) = ₹30,000              │
# │    - DTI = (Monthly Debt Obligations / Monthly Income) x 100                                                    │
# │    - DTI = (₹30,000 / ₹1,50,000) x 100 = **20%**                                                                │
# │                                                                                                                 │
# │  A DTI of 20% is generally considered healthy, indicating that you manage debt well relative to your income.    │
# │                                                                                                                 │
# │  # Key Recommendations                                                                                          │
# │  1. **Increase Savings Rate:** Aim to consistently save a higher percentage of your disposable income. Utilize  │
# │  the potential saving of ₹70,000 each month for greater security and investment growth.                         │
# │                                                                                                                 │
# │  2. **Debt Management:** Focus on paying down high-interest loans first, if any exist, as this will reduce      │
# │  overall debt faster. Consider consolidating loans for better interest rates.                                   │
# │                                                                                                                 │
# │  3. **Investment Strategy:** Review your current investments (₹10,00,000) to ensure they align with your risk   │
# │  tolerance and long-term financial goals. Diversification could enhance returns.                                │
# │                                                                                                                 │
# │  4. **Emergency Fund:** Aim to maintain at least 6 months of living expenses (₹80,000 x 6 = ₹4,80,000) in an    │
# │  easily accessible fund. Your current savings can mostly cover this need.                                       │
# │                                                                                                                 │
# │  5. **Review Expenses:** Regularly review and categorize your monthly expenses to identify areas where costs    │
# │  can be reduced or optimized.                                                                                   │
# │                                                                                                                 │
# │  6. **Insurance Coverage:** Ensure adequate health and life insurance coverage to protect your dependents and   │
# │  secure your financial future.                                                                                  │
# │                                                                                                                 │
# │  By implementing these recommendations, you can enhance your financial health, cultivate a more robust savings  │
# │  strategy, and navigate your debts more effectively.                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 5129feb6-f86f-4213-bd47-b3426c414961                                                                     │
# │  Agent: Financial Advisor                                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw='# Financial Health Overview\nBased on the information provided, we will analyze your financial situation comprehensively. Your monthly salary is ₹1,50,000, while your monthly expenses total ₹80,000. You have savings of ₹5,00,000 and investments amounting to ₹10,00,000. Additionally, you have outstanding loans of ₹20,00,000 with 2 dependents. Overall, by evaluating these figures, we can assess your financial health and provide actionable insights.\n\n## Current Financial Health Score: Average\nConsidering your income, expenses, savings, investments, and outstanding loans, your current financial health score is **Average**. While your income is substantial, the outstanding debt reduces your security, warranting a need for financial strategy refinement.\n\n# Income and Expense Analysis\n- **Monthly Income:** ₹1,50,000  \n- **Monthly Expenses:** ₹80,000  \n- **Disposable Income:** ₹1,50,000 - ₹80,000 = **₹70,000**  \n\nYour disposable income is ₹70,000 per month, indicating a healthy margin after meeting essential expenses. This surplus can be redirected into savings and investments.  \n\n# Savings Analysis  \n- **Current Savings:** ₹5,00,000  \n- **Monthly Savings Potential:** Given your disposable income of ₹70,000, you could potentially save this amount each month.  \n  - **Annual Savings Potential:** ₹70,000 x 12 = **₹8,40,000**  \n\nAssuming no expenses increase and prudent spending, your savings could grow substantially.\n\n# Debt Analysis\n- **Outstanding Loans:** ₹20,00,000  \n- **Debt-to-Income Ratio (DTI):**  \n  - Monthly debt obligations (assuming a typical installment of ₹30,000/month on loans) = ₹30,000  \n  - DTI = (Monthly Debt Obligations / Monthly Income) x 100  \n  - DTI = (₹30,000 / ₹1,50,000) x 100 = **20%**  \n\nA DTI of 20% is generally considered healthy, indicating that you manage debt well relative to your income.\n\n# Key Recommendations\n1. **Increase Savings Rate:** Aim to consistently save a higher percentage of your disposable income. Utilize the potential saving of ₹70,000 each month for greater security and investment growth.\n\n2. **Debt Management:** Focus on paying down high-interest loans first, if any exist, as this will reduce overall debt faster. Consider consolidating loans for better interest rates.\n\n3. **Investment Strategy:** Review your current investments (₹10,00,000) to ensure they align with your risk tolerance and long-term financial goals. Diversification could enhance returns.\n\n4. **Emergency Fund:** Aim to maintain at least 6 months of living expenses (₹80,000 x 6 = ₹4,80,000) in an easily accessible fund. Your current savings can mostly cover this need.\n\n5. **Review Expenses:** Regularly review and categorize your monthly expenses to identify areas where costs can be reduced or optimized.\n\n6. **Insurance Coverage:** Ensure adequate health and life insurance coverage to protect your dependents and secure your financial future.\n\nBy implementing these recommendations, you can enhance your financial health, cultivate a more robust savings strategy, and navigate your debts more effectively.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description="\nAnalyze the customer's financial situation based on the following inputs:\n- Monthly salary: ₹1,50,000\n- Monthly expenses: ₹80,000\n- Current savings: ₹5,00,000\n- Current investments: ₹10,00,000\n- Outstanding loans: ₹20,00,000\n- Number of dependents: 2\n\nProvide a detailed analysis including:\n1. Current financial health score (Good/Average/Needs Improvement)\n2. Monthly savings potential\n3. Debt-to-income ratio\n4. Basic recommendations for improvement\n\nFormat the output as a structured report with clear sections\n", name="\nAnalyze the customer's financial situation based on the following inputs:\n- Monthly salary: ₹1,50,000\n- Monthly expenses: ₹80,000\n- Current savings: ₹5,00,000\n- Current investments: ₹10,00,000\n- Outstanding loans: ₹20,00,000\n- Number of dependents: 2\n\nProvide a d ...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────────── Execution Traces ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  🔍 Detailed execution traces are available!                                                                    │
# │                                                                                                                 │
# │  View insights including:                                                                                       │
# │    • Agent decision-making process                                                                              │
# │    • Task execution flow and timing                                                                             │
# │    • Tool usage details                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Would you like to view your execution traces? [y/N] (20s timeout):
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 4db5d4fb-5e53-4361-b4b0-12de1c5ebdd5                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: # Financial Health Overview                                                                      │
# │  Based on the information provided, we will analyze your financial situation comprehensively. Your monthly      │
# │  salary is ₹1,50,000, while your monthly expenses total ₹80,000. You have savings of ₹5,00,000 and investments  │
# │  amounting to ₹10,00,000. Additionally, you have outstanding loans of ₹20,00,000 with 2 dependents. Overall,    │
# │  by evaluating these figures, we can assess your financial health and provide actionable insights.              │
# │                                                                                                                 │
# │  ## Current Financial Health Score: Average                                                                     │
# │  Considering your income, expenses, savings, investments, and outstanding loans, your current financial health  │
# │  score is **Average**. While your income is substantial, the outstanding debt reduces your security,            │
# │  warranting a need for financial strategy refinement.                                                           │
# │                                                                                                                 │
# │  # Income and Expense Analysis                                                                                  │
# │  - **Monthly Income:** ₹1,50,000                                                                                │
# │  - **Monthly Expenses:** ₹80,000                                                                                │
# │  - **Disposable Income:** ₹1,50,000 - ₹80,000 = **₹70,000**                                                     │
# │                                                                                                                 │
# │  Your disposable income is ₹70,000 per month, indicating a healthy margin after meeting essential expenses.     │
# │  This surplus can be redirected into savings and investments.                                                   │
# │                                                                                                                 │
# │  # Savings Analysis                                                                                             │
# │  - **Current Savings:** ₹5,00,000                                                                               │
# │  - **Monthly Savings Potential:** Given your disposable income of ₹70,000, you could potentially save this      │
# │  amount each month.                                                                                             │
# │    - **Annual Savings Potential:** ₹70,000 x 12 = **₹8,40,000**                                                 │
# │                                                                                                                 │
# │  Assuming no expenses increase and prudent spending, your savings could grow substantially.                     │
# │                                                                                                                 │
# │  # Debt Analysis                                                                                                │
# │  - **Outstanding Loans:** ₹20,00,000                                                                            │
# │  - **Debt-to-Income Ratio (DTI):**                                                                              │
# │    - Monthly debt obligations (assuming a typical installment of ₹30,000/month on loans) = ₹30,000              │
# │    - DTI = (Monthly Debt Obligations / Monthly Income) x 100                                                    │
# │    - DTI = (₹30,000 / ₹1,50,000) x 100 = **20%**                                                                │
# │                                                                                                                 │
# │  A DTI of 20% is generally considered healthy, indicating that you manage debt well relative to your income.    │
# │                                                                                                                 │
# │  # Key Recommendations                                                                                          │
# │  1. **Increase Savings Rate:** Aim to consistently save a higher percentage of your disposable income. Utilize  │
# │  the potential saving of ₹70,000 each month for greater security and investment growth.                         │
# │                                                                                                                 │
# │  2. **Debt Management:** Focus on paying down high-interest loans first, if any exist, as this will reduce      │
# │  overall debt faster. Consider consolidating loans for better interest rates.                                   │
# │                                                                                                                 │
# │  3. **Investment Strategy:** Review your current investments (₹10,00,000) to ensure they align with your risk   │
# │  tolerance and long-term financial goals. Diversification could enhance returns.                                │
# │                                                                                                                 │
# │  4. **Emergency Fund:** Aim to maintain at least 6 months of living expenses (₹80,000 x 6 = ₹4,80,000) in an    │
# │  easily accessible fund. Your current savings can mostly cover this need.                                       │
# │                                                                                                                 │
# │  5. **Review Expenses:** Regularly review and categorize your monthly expenses to identify areas where costs    │
# │  can be reduced or optimized.                                                                                   │
# │                                                                                                                 │
# │  6. **Insurance Coverage:** Ensure adequate health and life insurance coverage to protect your dependents and   │
# │  secure your financial future.                                                                                  │
# │                                                                                                                 │
# │  By implementing these recommendations, you can enhance your financial health, cultivate a more robust savings  │
# │  strategy, and navigate your debts more effectively.                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
